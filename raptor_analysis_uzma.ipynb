# %% [markdown]
# # Exploratory Analysis of RAPTOR metrics in Modern NBA
#
# ----
#
# ## Analysis

# %%
# Dependdencies and set up 

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the csv data file

df=pd.read_csv("latest_RAPTOR_by_team.csv")

# %%
df.head()
# Out:
#         player_name  player_id  season season_type team  poss    mp  \
# 0  Precious Achiuwa  achiupr01    2023          RS  TOR  2328  1140
# 1      Steven Adams  adamsst01    2023          RS  MEM  2391  1133
# 2       Bam Adebayo  adebaba01    2023          PO  MIA  1681   850
# 3       Bam Adebayo  adebaba01    2023          RS  MIA  5252  2598
# 4      Ochai Agbaji  agbajoc01    2023          RS  UTA  2604  1209
#
#    raptor_box_offense  raptor_box_defense  raptor_box_total  ...  \
# 0           -2.442459            0.605968         -1.836491  ...
# 1           -0.539149            4.174473          3.635324  ...
# 2           -2.042952            1.343185         -0.699767  ...
# 3           -1.861596            2.663534          0.801939  ...
# 4           -1.323938           -2.198396         -3.522334  ...
#
#    raptor_offense  raptor_defense  raptor_total  war_total  war_reg_season  \
# 0       -1.771180       -0.283673     -2.054852   0.400488        0.400488
# 1        0.416279        3.550985      3.967264   3.892111        3.892111
# 2       -1.667750        1.933160      0.265409   1.342984        0.000000
# 3       -1.154758        2.718460      1.563703   5.692164        5.692164
# 4       -1.010696       -1.964927     -2.975622  -0.139469       -0.139469
#
#    war_playoffs  predator_offense  predator_defense  predator_total  \
# 0      0.000000         -1.867986         -0.182806       -2.050792
# 1      0.000000          0.025097          3.570024        3.595120
# 2      1.342984         -0.347436          2.167669        1.820232
# 3      0.000000         -0.957159          2.658545        1.701386
# 4      0.000000         -1.145865         -2.506387       -3.652252
#
#    pace_impact
# 0    -0.956065
# 1     0.237905
# 2    -0.415820
# 3    -0.452741
# 4     0.216216
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['player_name', 'player_id', 'season', 'season_type', 'team', 'poss',
#        'mp', 'raptor_box_offense', 'raptor_box_defense', 'raptor_box_total',
#        'raptor_onoff_offense', 'raptor_onoff_defense', 'raptor_onoff_total',
#        'raptor_offense', 'raptor_defense', 'raptor_total', 'war_total',
#        'war_reg_season', 'war_playoffs', 'predator_offense',
#        'predator_defense', 'predator_total', 'pace_impact'],
#       dtype='object')

# %%
df.shape
# Out:
# (826, 23)

# %%
# Find rows and columns with null values.

df.isnull()
# Out:
#      player_name  player_id  season  season_type   team   poss     mp  \
# 0          False      False   False        False  False  False  False
# 1          False      False   False        False  False  False  False
# 2          False      False   False        False  False  False  False
# 3          False      False   False        False  False  False  False
# 4          False      False   False        False  False  False  False
# ..           ...        ...     ...          ...    ...    ...    ...
# 821        False      False   False        False  False  False  False
# 822        False      False   False        False  False  False  False
# 823        False      False   False        False  False  False  False
# 824        False      False   False        False  False  False  False
# 825        False      False   False        False  False  False  False
#
#      raptor_box_offense  raptor_box_defense  raptor_box_total  ...  \
# 0                 False               False             False  ...
# 1                 False               False             False  ...
# 2                 False               False             False  ...
# 3                 False               False             False  ...
# 4                 False               False             False  ...
# ..                  ...                 ...               ...  ...
# 821               False               False             False  ...
# 822               False               False             False  ...
# 823               False               False             False  ...
# 824               False               False             False  ...
# 825               False               False             False  ...
#
#      raptor_offense  raptor_defense  raptor_total  war_total  war_reg_season  \
# 0             False           False         False      False           False
# 1             False           False         False      False           False
# 2             False           False         False      False           False
# 3             False           False         False      False           False
# 4             False           False         False      False           False
# ..              ...             ...           ...        ...             ...
# 821           False           False         False      False           False
# 822           False           False         False      False           False
# 823           False           False         False      False           False
# 824           False           False         False      False           False
# 825           False           False         False      False           False
#
#      war_playoffs  predator_offense  predator_defense  predator_total  \
# 0           False             False             False           False
# 1           False             False             False           False
# 2           False             False             False           False
# 3           False             False             False           False
# 4           False             False             False           False
# ..            ...               ...               ...             ...
# 821         False             False             False           False
# 822         False             False             False           False
# 823         False             False             False           False
# 824         False             False             False           False
# 825         False             False             False           False
#
#      pace_impact
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 821        False
# 822        False
# 823        False
# 824        False
# 825        False
#
# [826 rows x 23 columns]

# %%
# Find rows and columns with duplicate values.

# %% [markdown]
# ## Summary Statistics

# %%
df.describe()
# Out:
#        season         poss           mp  raptor_box_offense  \
# count   826.0   826.000000   826.000000          826.000000
# mean   2023.0  1613.684019   769.199758           -1.232587
# std       0.0  1636.953006   782.580975            5.511909
# min    2023.0     1.000000     0.000000          -74.359220
# 25%    2023.0   249.250000   118.000000           -2.601496
# 50%    2023.0   962.500000   459.000000           -1.039920
# 75%    2023.0  2737.000000  1278.250000            0.942240
# max    2023.0  6026.000000  2842.000000           29.980748
#
#        raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# count          826.000000        826.000000            826.000000
# mean            -0.265964         -1.498551             -2.149929
# std              5.644426          8.080948              9.597225
# min            -64.933861        -71.012853            -74.277126
# 25%             -1.963951         -3.822264             -4.191947
# 50%             -0.237402         -0.974020             -1.030933
# 75%              1.367241          1.472506              1.644804
# max             58.195329         57.253239             30.687169
#
#        raptor_onoff_defense  raptor_onoff_total  raptor_offense  \
# count            826.000000          826.000000      826.000000
# mean               0.945157           -1.204772       -1.497868
# std                6.990852           10.653763        5.990461
# min              -35.366970          -70.845934      -78.659427
# 25%               -2.207020           -4.678641       -2.997662
# 50%                0.104449           -0.736064       -0.969355
# 75%                2.789355            2.998780        0.981602
# max               61.557315           55.533363       31.083234
#
#        raptor_defense  raptor_total   war_total  war_reg_season  war_playoffs  \
# count      826.000000    826.000000  826.000000      826.000000    826.000000
# mean        -0.028621     -1.526489    1.126431        1.016177      0.110254
# std          5.317025      8.067727    2.303181        2.301489      0.481804
# min        -54.515230    -75.385610   -3.045436       -3.045436     -0.547170
# 25%         -1.855767     -3.810309   -0.055486        0.000000      0.000000
# 50%         -0.144062     -0.986194    0.234817        0.007369      0.000000
# 75%          1.613217      1.577875    1.524143        1.297288      0.000000
# max         50.486140     59.363461   20.310952       20.310952      5.556234
#
#        predator_offense  predator_defense  predator_total  pace_impact
# count        826.000000        826.000000      826.000000   826.000000
# mean          -1.375391         -0.613072       -1.988463     0.130569
# std            5.269645          5.211631        8.106104     1.221475
# min          -75.354256        -59.165453      -79.698981    -4.220434
# 25%           -2.976436         -2.138523       -4.447815    -0.467297
# 50%           -1.171339         -0.387268       -1.349334     0.017906
# 75%            0.851118          1.292142        1.464437     0.551239
# max           21.382141         47.358320       68.740461     9.876947

# %% [markdown]
# #### Statistics by team

# %% [markdown]
# #### Statistics by player

# %% [markdown]
# ### Does the amount of possessions per player greatly impact that player’s overall RAPTOR ratings? Why or why not?

# %%
possesion=df.groupby("player_name")["poss"].sum()
possesion=pd.DataFrame(possesion)
possesion=possesion.sort_values(by="poss",ascending=False)

# %%
possesion=possesion.head()
possesion
# Out:
#                  poss
# player_name
# Jayson Tatum     7273
# Bam Adebayo      6933
# Jaylen Brown     6542
# Nikola Jokic     6435
# Anthony Edwards  6418

# %%
possesion.plot(kind="bar",rot = 45)
plt.title("Possessions per Player")
plt.xlabel("Player Name")
plt.ylabel("Possessions")
plt.show()

# %% [markdown]
# ### Which team displayed the highest/lowest RAPTOR ratings across the 2022-23 season across all players? How does this data compare to their predictive PREDATOR model?

# %% [markdown]
# ### How accurate are the overall results of predictive-RAPTOR, which was used for the historical data charts (1977-2013), compared to those of modern RAPTOR’s integration (2013-Present)?

# %% [markdown]
# ### In what ways does the RAPTOR model accurately showcase a team’s Win/Loss ratio? In what ways does it not

# %% [markdown]
# ### How do these statistics line up by player in relation to the top players/teams (MVPs) of the 2022-2023 season?
